# %% [markdown]
# # IBM Data Science Capstone Project

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import requests
import geocoder
from bs4 import BeautifulSoup
import folium
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ### Download and create pandas Dataframe for Canada's Postal Codes

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
req = requests.get(url)
if req.status_code == 200:
    print('Requisition OK')
    content = req.content
# Out:
# Requisition OK

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
table = soup.find(name='table')

# %%
table_str = str(table)
df = pd.read_html(table_str)[0]

# %%
print(df.shape)
print(df.columns)
# Out:
# (103, 3)
# Index(['Postal code', 'Borough', 'Neighborhood'], dtype='object')

# %% [markdown]
# ### Clean up and organize the Dataframe

# %%
df = df[df['Borough']!='Not assigned'].reset_index().drop('index',axis=1)

# %%
df['Neighborhood'] = df['Neighborhood'].str.replace(' / ',',')

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                             Regent Park,Harbourfront
# 3                      Lawrence Manor,Lawrence Heights
# 4           Queen's Park,Ontario Provincial Government
# ..                                                 ...
# 98         The Kingsway,Montgomery Road,Old Mill North
# 99                                Church and Wellesley
# ...

# %% [markdown]
# ### Add Coordinates to Dataframe

# %%
coordinates = pd.read_csv('Geospatial_Coordinates.csv')

# %%
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df = df.join(coordinates,how='left')

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                           Neighborhood Postal Code   Latitude  \
# 0                                            Parkwoods         M1B  43.806686
# 1                                     Victoria Village         M1C  43.784535
# 2                             Regent Park,Harbourfront         M1E  43.763573
# 3                      Lawrence Manor,Lawrence Heights         M1G  43.770992
# 4           Queen's Park,Ontario Provincial Government         M1H  43.773136
# ..                                                 ...         ...        ...
# ...

# %% [markdown]
# ### Visualize the Data

# %%
latitude = df['Latitude'].mean()
longitude = df['Longitude'].mean()

# %%
_map = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{} - {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(_map)  
_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Clustering data by location

# %% [markdown]
# #### Define number of clusters

# %%
df_cluster = df[['Latitude','Longitude']]

inertia_list=[]

for k in range(2,11,1):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(df_cluster)
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(2,11,1),inertia_list)

# %% [markdown]
# #### Using k=3

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(df_cluster)
df.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
_map = folium.Map(location=[latitude, longitude], zoom_start=10,tiles='Stamen Terrain')

kclusters=3

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat, lng, borough, neighborhood,cluster in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood'], df['Cluster Labels']):
    label = '{} - {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(_map)  
_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### First Cluster (Central)

# %%
df.loc[df['Cluster Labels'] == 0, df.columns[[1] + list(range(5, df.shape[1]))]].head()
# Out:
#    Postal code   Latitude  Longitude
# 29         M4H  43.767980 -79.487262
# 30         M5H  43.737473 -79.464763
# 31         M6H  43.739015 -79.506944
# 32         M1J  43.728496 -79.495697
# 33         M2J  43.761631 -79.520999

# %% [markdown]
# #### Second Cluster (Eastern Town)

# %%
df.loc[df['Cluster Labels'] == 1, df.columns[[1] + list(range(5, df.shape[1]))]].head()
# Out:
#    Postal code   Latitude  Longitude
# 19         M4E  43.786947 -79.385975
# 20         M5E  43.757490 -79.374714
# 21         M6E  43.789053 -79.408493
# 22         M1G  43.770120 -79.408493
# 23         M4G  43.752758 -79.400049

# %% [markdown]
# #### Third Cluster (Western Town)

# %%
df.loc[df['Cluster Labels'] == 2, df.columns[[1] + list(range(5, df.shape[1]))]].head()
# Out:
#   Postal code   Latitude  Longitude
# 0         M3A  43.806686 -79.194353
# 1         M4A  43.784535 -79.160497
# 2         M5A  43.763573 -79.188711
# 3         M6A  43.770992 -79.216917
# 4         M7A  43.773136 -79.239476

# %%
rainbow
# Out:
# ['#8000ff', '#80ffb4', '#ff0000']
